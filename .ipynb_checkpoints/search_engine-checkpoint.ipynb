# %% [markdown]
# ### Steps:
#
# - represent the documents in form of vectors
#
# - find the cosine similarity between the documents
#
# - prepare the document-term matrix (indexing) for fast access
#
# - get the most similar documents

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %%
## Load the data
dataframe = pd.read_csv('./flaskapp/models/output/results_dataframe.csv')

# %%
# Cast as a list of values for calculating weights
text_data= dataframe['processed_text'].values.tolist()

# %%
text_data[:5]
# Out:
# ['pandemic-09-h1n1 virus cause pandemic start 2 quarter 2009 world prepare face pandemic anticipate decade country include india detail pandemic preparedness plan good ahead actual occurrence infection rapidly spread country 2 3 month national tactic slow importation international air traveler slow spread city major town 75 infect person urban dweller suggest effort concentrate urban community general illness pandemic influenza similar endemic/seasonal influenza insufficient epidemiological clinical datum hope unprecedented experience manage pandemic encourage government india plan confront endemic/seasonal influenza systematically pandemic reach peak september/october decline',
#  'aim study evaluation clinical radiologic outcome parallel graft treatment patient fail prior endovascular aneurysm repair type ia endoleak methods prospectively collect clinical radiologic datum consecutive patient prior endovascular aneurysm repair evidence type ia endoleak analyze patient treat january 2009 november 2014 use parallel graft ie chimney/snorkel periscope graft abdominal endovascular device primary outcome study technical success secondary outcome patency chimney graft shrinkage aneurysm morphology results technical success 94.4 17 18 patient evidence persistent type ia endoleak triple chimney graft placement treat onyx embolization covidien plymouth minn successfully mean preoperative postoperative aneurysm diameter 7.1 ± 1.7 7.0 ± 2 cm primary patency chimney graft 96.7 assist patency 100 successful retrograde recanalization acute occlusion superior mesenteric artery celiac trunk gastroduodenal artery patient undergo sandwich technique transfemoral placement flexible viabahn w. l. gore associates flagstaff ariz impossible catheterization target vessel upper extremity present contain rupture cause gutter-associated endoleak undergo urgent embolization onyx successfully procedure-related death open conversion observe entire follow-up period conclusions use parallel graft midterm safety feasibility low incidence persistent endoleaks require intervention progression aneurysm diameter reproducible result vascular center establish chimney technique treatment type endoleaks viable endovascular modality',
#  'exploring use forecast model simulation tool estimate demand reduce wait time patient emergency departments eds methods analysis base datum collect 2013 ed recanto das emas federal district brasil use manchester triage system total 100 consecutive patient include 70 yellow 70 30 green 30 flow pattern observe wait time inter-arrival time patient collect process map demand capacity datum use build simulation calibrate observe flow time what-if analysis conduct reduce wait time results green yellow patient arrival-time pattern similar inter-arrival time 5 38 minute respectively wait-time 14 minute yellow patient 4 hour green patient physician staff comprise doctor shift simulation predict allocate doctor shift reduce wait-time 2.5 hour green patient small impact yellow patient wait-time maintaining doctor allocate doctor exclusively green patient reduce wait time 1.5 hour green patient increase 15 minute yellow patient simulation scenario employ doctor shift doctor exclusively green patient conclusion waiting time reduce balance allocation doctor green yellow patient match availability doctor forecast demand pattern simulations eds use generate test solution decrease overcrowd',
#  'work inhibitory activity pyridine n-oxide derivative human severe acute respiratory syndrome sars predict term quantitative structure – activity relationship qsar model model develope aid multivariate adaptive regression spline mars adaptive neuro-fuzzy inference system anfis combine shuffle cross-validation technique shuffle mars algorithm utilize select important variable qsar model variable use input anfis predict sars inhibitory activity pyridine n-oxide derivative datum set 119 drug-like compound code calculate meaningful molecular descriptor descriptor describe inhibition mechanism solvation connectivity index length breadth ratio relative negative charge harmonic oscillator aromatic index average molecular weight total path count parameter topological electronic geometric constitutional aromaticity descriptor statistical parameter r 2 root mean square error rmse 0.884 0.359 respectively accuracy robustness shuffle mars – anfis model predict inhibition behavior pyridine n-oxide derivative pic50 illustrate use leave-one-out leave-multiple-out cross-validation technique y-randomization comparison result propose model ga-pls-anfis shuffle mars – anfis model superior consider tool predict inhibitory behavior sars drug-like molecule',
#  'single-incision laparoscopic surgery sils emerge alternative technique conventional laparoscopy treatment common surgical disease despite wide use adoption sils child slow broad application minimally invasive technique child general historically lag adult paper review evolution sils original conception application field pediatric surgery']

# %%
# Calculate TF-IDF matrix
def tf_idf(search_keys, data):
    tfidf_vectorizer = TfidfVectorizer()
    tfidf_weights_matrix = tfidf_vectorizer.fit_transform(data)
    search_query_weights = tfidf_vectorizer.transform([search_keys])

    return search_query_weights, tfidf_weights_matrix

# Calculate the cosine similarity between search query and TF-IDF vectors
def cos_similarity(search_query_weights, tfidf_weights_matrix):
    cosine_sim = cosine_similarity(search_query_weights, tfidf_weights_matrix)
    similarity_list = cosine_sim[0]

    return similarity_list

# Calculate number of relevant vectors
def calculate_num_vectors(cosine_similarity):

    num = 0
    for i in cosine_similarity:
        if i != 0.0:
            num += 1
    return num

# Calculate the most relevant vectors
def most_similar(similarity_list, N):

    most_similar = []

    while N > 0:
        tmp_index = np.argmax(similarity_list)
        most_similar.append(tmp_index)
        similarity_list[tmp_index] = 0
        N -= 1

    return most_similar

# Create weights at specific index for quick retrieval
def create_matrix_dict(cosine_similarity):

    matrix_dict = {}

    iter_counter = 0
    for i in cosine_similarity:
        matrix_dict[iter_counter] = i
        iter_counter += 1

    return matrix_dict

# -----------
# Return the recipes with relevant search term
def return_relevant_recipes(search_term):

    # Create local variables
    # convert_documents to vector representations
    search, matrix = tf_idf(search_term, text_data)
    
    # Find the cosine similarity
    cosine_sim_list = cos_similarity(search, matrix)
    
    # Get the number of relevant documents
    num_relevant_vectors = calculate_num_vectors(cosine_sim_list)
    
    # Prepare the " indexing " (one of stages in web information retrieval) for faster retrieval 
    # (Similar concept is also used by the Google, namely stored as document-term matrix)
    dictionary = create_matrix_dict(cosine_sim_list)
    
    # Get the most similar items
    list_of_most_similar = most_similar(cosine_sim_list, num_relevant_vectors)

    df = pd.DataFrame()

    for index in list_of_most_similar:

        recipe = dataframe.iloc[index]

        if df.empty:

            to_dataframe = recipe.to_frame()
            df = to_dataframe.T

        else:
            to_dataframe = recipe.to_frame()
            df = pd.concat([df, to_dataframe.T], join='outer')

    ### Specify the required columns here
    columns = dataframe.columns

    return df[columns]

# %%
return_relevant_recipes('covid')
# Out:
#     Unnamed: 0  cord_uid                                       sha  \
# 54      101466  dblg9wfk                                       NaN
# 704     148646  69nfi379  6b45aa983702a9425fd6604470b931906f12b19c
# 555     109522  9k0741ct                                       NaN
# 85      156229  zzkqb0u2  056f35bf25005ec3974c0633a63492b675a17849
# 403      69749  6n29eryp  56344abdbb723e92ee5d28d38f6bd87d37f35f0e
# ..         ...       ...                                       ...
# 758     165987  443gyw3e  878c67df99d516cc7670e4de57d54dd393880b6b
# 571     105282  5d0gev9e                                       NaN
# 45      191775  dbxufi3m  38197b689df3566474ed08974a9a6cb220686ab1
# 889     188003  me6qusdz  eeb37b751a171b7d78b53b4f5b32d0a10c877335
# 189      72121  0vecbxny  79e4796fc972ca51a607b515050e1b5c59185cd1
#
#                    source_x  \
# 54                      WHO
# 704            Medline; PMC
# 555                     WHO
# 85             Medline; PMC
# 403                 MedRxiv
# ..                      ...
# 758  Elsevier; Medline; PMC
# 571                     WHO
# 45             Medline; PMC
# 889  Elsevier; Medline; PMC
# 189                 MedRxiv
#
#                                                  title  \
# 54   Target Virus or Target Ourselves for COVID-19 ...
# 704  COVID-19: POSTMORTEM DIAGNOSTIC AND BIOSAFETY ...
# 555          Clinical and imaging features of COVID-19
# 85   Ideas for how informaticians can get involved ...
# 403  Psychiatric symptoms, risk, and protective fac...
# ..                                                 ...
# 758  Telemedicine for ENT: effect on quality of car...
# 571  An international multicentre study of protocol...
# 45   Vertebrates on the brink as indicators of biol...
# 889  Pediatrician attitudes toward and experiences ...
# 189  Impact of viral epidemic outbreaks on mental h...
#
#                               doi       pmcid pubmed_id      license  \
# 54                            NaN         NaN       NaN          unk
# 704  10.1097/paf.0000000000000567  PMC7202125  32379077  cc-by-nc-nd
# 555                           NaN         NaN       NaN          unk
# 85     10.1186/s13040-020-00213-y  PMC7216865  32419848        cc-by
# 403   10.1101/2020.07.03.20144931         NaN       NaN      medrxiv
# ..                            ...         ...       ...          ...
# 758   10.1016/j.anorl.2020.06.014  PMC7306717  32624390    els-covid
# 571                           NaN         NaN       NaN          unk
# 45        10.1073/pnas.1922686117  PMC7306750  32482862        cc-by
# 889    10.1016/j.acap.2020.05.004  PMC7207114  32437881    els-covid
# 189   10.1101/2020.04.02.20048892         NaN       NaN      medrxiv
#
#                                               abstract  ...  \
# 54   The COVID-19 pandemic, after it was reported i...  ...
# 704  As a result of the 2019 novel human coronaviru...  ...
# 555  Since December 2019, multiple cases of 2019 co...  ...
# 85   The coronavirus disease 2019 (COVID-19) pandem...  ...
# 403  This study investigated psychiatric symptoms (...  ...
# ..                                                 ...  ...
# 758  Abstract Aims To assess the benefit of telemed...  ...
# 571  BACKGROUND: The outbreak of Covid-19 has vastl...  ...
# 45   The ongoing sixth mass species extinction is t...  ...
# 889  Abstract Background: The American Academy of P...  ...
# 189  Objectives: To examine the impact of providing...  ...
#
#                                    pmc_json_files  \
# 54                                            NaN
# 704  document_parses/pmc_json/PMC7202125.xml.json
# 555                                           NaN
# 85   document_parses/pmc_json/PMC7216865.xml.json
# 403                                           NaN
# ..                                            ...
# 758                                           NaN
# 571                                           NaN
# 45   document_parses/pmc_json/PMC7306750.xml.json
# 889                                           NaN
# 189                                           NaN
#
#                                                    url        s2_id language  \
# 54                                                 NaN  2.15747e+08       en
# 704  https://doi.org/10.1097/paf.0000000000000567; ...  2.18532e+08       en
# 555                                                NaN  2.16554e+08       en
# 85   https://www.ncbi.nlm.nih.gov/pubmed/32419848/;...  2.18605e+08       en
# 403  http://medrxiv.org/cgi/content/short/2020.07.0...  2.20335e+08       en
# ..                                                 ...          ...      ...
# 758  https://api.elsevier.com/content/article/pii/S...  2.19958e+08       en
# 571                                                NaN  2.18855e+08       en
# 45   https://www.ncbi.nlm.nih.gov/pubmed/32482862/;...   2.1917e+08       en
# 889  https://www.sciencedirect.com/science/article/...  2.18552e+08       en
# 189  http://medrxiv.org/cgi/content/short/2020.04.0...  2.15782e+08       en
#
#                                         processed_text words_count   y  \
# 54   covid-19 pandemic report december 2019 highly ...          48  18
# 704  result 2019 novel human coronavirus covid-19 g...         105  18
# 555  december 2019 multiple case 2019 coronavirus d...          92  18
# 85   coronavirus disease 2019 covid-19 pandemic sig...          61  18
# 403  study investigate psychiatric symptom depressi...         166  18
# ..                                                 ...         ...  ..
# 758  aims assess benefit telemedicine consultation ...         137  87
# 571  background outbreak covid-19 vastly increase o...         170  18
# 45   ongoing 6 mass species extinction result destr...         140  18
# 889  background american academy pediatrics 2015 po...         156  18
# 189  objectives examine impact provide healthcare h...         331  18
#
#                                               keywords tsne_embedding_coord1  \
# 54   ['covid-', 'disease', 'virus', 'cell', 'study'...              -4.83305
# 704  ['covid-', 'disease', 'virus', 'cell', 'study'...                -5.479
# 555  ['covid-', 'disease', 'virus', 'cell', 'study'...              -6.28544
# 85   ['covid-', 'disease', 'virus', 'cell', 'study'...               11.9508
# 403  ['covid-', 'disease', 'virus', 'cell', 'study'...              -13.1674
# ..                                                 ...                   ...
# 758                                                NaN              -23.9344
# 571  ['covid-', 'disease', 'virus', 'cell', 'study'...              -27.7667
# 45   ['covid-', 'disease', 'virus', 'cell', 'study'...               22.1392
# 889  ['covid-', 'disease', 'virus', 'cell', 'study'...              -23.3443
# 189  ['covid-', 'disease', 'virus', 'cell', 'study'...               3.61333
#
#     tsne_embedding_coord2
# 54                3.06372
# 704             0.0222779
# 555              0.531187
# 85               -2.46405
# 403               3.70276
# ..                    ...
# 758              -15.7141
# 571               2.31984
# 45                18.6933
# 889                9.8803
# 189              -1.98995
#
# [267 rows x 27 columns]
